# %% [markdown]
# ## WIND POWER GENERATION FORECASTING

# %%
# importing all the necessary libraries
import pandas as pd # Data Manipulation
import numpy as np # Numerical Python - Linear Algebra
import matplotlib.pyplot as plt # Visualization Lib
import seaborn as sns
from sklearn.model_selection import train_test_split # sklearn - ML
from sklearn.preprocessing import StandardScaler # Scaling

# %%
# Load the csv (Dataset) files
location1=pd.read_csv('Location1.csv')
location2=pd.read_csv('Location2.csv')
location3=pd.read_csv('Location3.csv')
location4=pd.read_csv('Location4.csv')

# %%
# See the location 1
location1.head() # Show you top 5 rows
# Out:
#                   Time  temperature_2m  relativehumidity_2m  dewpoint_2m  \
# 0  2017-01-02 00:00:00            28.5                   85         24.5
# 1  2017-01-02 01:00:00            28.4                   86         24.7
# 2  2017-01-02 02:00:00            26.8                   91         24.5
# 3  2017-01-02 03:00:00            27.4                   88         24.3
# 4  2017-01-02 04:00:00            27.3                   88         24.1
#
#    windspeed_10m  windspeed_100m  winddirection_10m  winddirection_100m  \
# 0           1.44            1.26                146                 162
# 1           2.06            3.99                151                 158
# 2           1.30            2.78                148                 150
# 3           1.30            2.69                 58                 105
# 4           2.47            4.43                 58                  84
#
#    windgusts_10m   Power
# 0            1.4  0.1635
# 1            4.4  0.1424
# 2            3.2  0.1214
# 3            1.6  0.1003
# 4            4.0  0.0793

# %%
# Add a new column to identify the location
location1['Location']='Location1'
location2['Location']='Location2'
location3['Location']='Location3'
location4['Location']='Location4'

# Concatenate to a dataframe
merged_data=pd.concat([location1, location2, location3, location4], ignore_index=True)

merged_data.head()
# Out:
#                   Time  temperature_2m  relativehumidity_2m  dewpoint_2m  \
# 0  2017-01-02 00:00:00            28.5                   85         24.5
# 1  2017-01-02 01:00:00            28.4                   86         24.7
# 2  2017-01-02 02:00:00            26.8                   91         24.5
# 3  2017-01-02 03:00:00            27.4                   88         24.3
# 4  2017-01-02 04:00:00            27.3                   88         24.1
#
#    windspeed_10m  windspeed_100m  winddirection_10m  winddirection_100m  \
# 0           1.44            1.26                146                 162
# 1           2.06            3.99                151                 158
# 2           1.30            2.78                148                 150
# 3           1.30            2.69                 58                 105
# 4           2.47            4.43                 58                  84
#
#    windgusts_10m   Power   Location
# 0            1.4  0.1635  Location1
# 1            4.4  0.1424  Location1
# 2            3.2  0.1214  Location1
# 3            1.6  0.1003  Location1
# 4            4.0  0.0793  Location1

# %%
# Ssave the merged dataset to a new CSV file
merged_data.to_csv('merged_locations.csv', index=False)

# %%
# To see the basic information about the dataset
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175200 entries, 0 to 175199
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Time                 175200 non-null  object
#  1   temperature_2m       175200 non-null  float64
#  2   relativehumidity_2m  175200 non-null  int64
#  3   dewpoint_2m          175200 non-null  float64
#  4   windspeed_10m        175200 non-null  float64
#  5   windspeed_100m       175200 non-null  float64
#  6   winddirection_10m    175200 non-null  int64
#  7   winddirection_100m   175200 non-null  int64
#  8   windgusts_10m        175200 non-null  float64
#  9   Power                175200 non-null  float64
#  10  Location             175200 non-null  object
# dtypes: float64(6), int64(3), object(2)
# memory usage: 14.7+ MB

# %%
# To check the statistics of Dataset
merged_data.describe().T
# Out:
#                         count        mean         std   min       25%  \
# temperature_2m       175200.0   46.655994   22.012738 -31.2   30.2000
# relativehumidity_2m  175200.0   70.155291   17.326678   9.0   57.0000
# dewpoint_2m          175200.0   36.516241   20.933153 -36.2   21.9000
# windspeed_10m        175200.0    4.157639    2.012682   0.0    2.6300
# windspeed_100m       175200.0    6.879334    3.043964   0.0    4.7000
# winddirection_10m    175200.0  201.589446   99.639040   1.0  130.0000
# winddirection_100m   175200.0  201.539070  100.683777   0.0  129.0000
# windgusts_10m        175200.0    8.038205    3.617488   0.5    5.3000
# Power                175200.0    0.303429    0.257325   0.0    0.0877
#
#                           50%       75%       max
# temperature_2m        46.9000   65.3000  101.7000
# relativehumidity_2m   72.0000   84.0000  100.0000
# dewpoint_2m           36.2000   54.6000   78.7000
# windspeed_10m          3.8500    5.3800   18.5300
# windspeed_100m         6.6800    8.8000   24.5900
# winddirection_10m    211.0000  288.0000  360.0000
# winddirection_100m   211.0000  290.0000  360.0000
# windgusts_10m          7.6000   10.3000   29.2000
# Power                  0.2331    0.4742    0.9994

# %%
# Check the missing values
merged_data.isnull().sum()
# Out:
# Time                   0
# temperature_2m         0
# relativehumidity_2m    0
# dewpoint_2m            0
# windspeed_10m          0
# windspeed_100m         0
# winddirection_10m      0
# winddirection_100m     0
# windgusts_10m          0
# Power                  0
# Location               0
# dtype: int64

# %%
# To check the duplicated rows
merged_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Encode the categorical variables
merged_data=pd.get_dummies(merged_data, columns=['Location'], drop_first=True)
merged_data.head()
# Out:
#                   Time  temperature_2m  relativehumidity_2m  dewpoint_2m  \
# 0  2017-01-02 00:00:00            28.5                   85         24.5
# 1  2017-01-02 01:00:00            28.4                   86         24.7
# 2  2017-01-02 02:00:00            26.8                   91         24.5
# 3  2017-01-02 03:00:00            27.4                   88         24.3
# 4  2017-01-02 04:00:00            27.3                   88         24.1
#
#    windspeed_10m  windspeed_100m  winddirection_10m  winddirection_100m  \
# 0           1.44            1.26                146                 162
# 1           2.06            3.99                151                 158
# 2           1.30            2.78                148                 150
# 3           1.30            2.69                 58                 105
# 4           2.47            4.43                 58                  84
#
#    windgusts_10m   Power  Location_Location2  Location_Location3  \
# 0            1.4  0.1635               False               False
# 1            4.4  0.1424               False               False
# 2            3.2  0.1214               False               False
# 3            1.6  0.1003               False               False
# 4            4.0  0.0793               False               False
#
#    Location_Location4
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False

# %%
merged_data.columns
# Out:
# Index(['Time', 'temperature_2m', 'relativehumidity_2m', 'dewpoint_2m',
#        'windspeed_10m', 'windspeed_100m', 'winddirection_10m',
#        'winddirection_100m', 'windgusts_10m', 'Power', 'Location_Location2',
#        'Location_Location3', 'Location_Location4'],
#       dtype='object')

# %%
# Let's remove time col
merged_data.drop('Time', axis=1, inplace=True)

# %%
merged_data.head()
# Out:
#    temperature_2m  relativehumidity_2m  dewpoint_2m  windspeed_10m  \
# 0            28.5                   85         24.5           1.44
# 1            28.4                   86         24.7           2.06
# 2            26.8                   91         24.5           1.30
# 3            27.4                   88         24.3           1.30
# 4            27.3                   88         24.1           2.47
#
#    windspeed_100m  winddirection_10m  winddirection_100m  windgusts_10m  \
# 0            1.26                146                 162            1.4
# 1            3.99                151                 158            4.4
# 2            2.78                148                 150            3.2
# 3            2.69                 58                 105            1.6
# 4            4.43                 58                  84            4.0
#
#     Power  Location_Location2  Location_Location3  Location_Location4
# 0  0.1635               False               False               False
# 1  0.1424               False               False               False
# 2  0.1214               False               False               False
# 3  0.1003               False               False               False
# 4  0.0793               False               False               False

# %%
location2.head()
# Out:
#                   Time  temperature_2m  relativehumidity_2m  dewpoint_2m  \
# 0  2017-01-02 00:00:00            14.5                   91         12.4
# 1  2017-01-02 01:00:00            14.5                   92         12.7
# 2  2017-01-02 02:00:00            14.7                   92         12.7
# 3  2017-01-02 03:00:00            14.7                   92         12.8
# 4  2017-01-02 04:00:00            14.8                   92         12.9
#
#    windspeed_10m  windspeed_100m  winddirection_10m  winddirection_100m  \
# 0           6.37            9.58                 68                  72
# 1           6.46            9.23                 68                  72
# 2           6.18            9.27                 67                  74
# 3           5.91            9.08                 62                  69
# 4           5.88            8.72                 58                  65
#
#    windgusts_10m   Power   Location
# 0            9.9  0.2574  Location2
# 1            9.5  0.2535  Location2
# 2            9.4  0.2497  Location2
# 3            9.1  0.2458  Location2
# 4            8.7  0.2419  Location2

# %%
location3.head()
# Out:
#                   Time  temperature_2m  relativehumidity_2m  dewpoint_2m  \
# 0  2017-01-02 00:00:00            29.7                   55         15.4
# 1  2017-01-02 01:00:00            29.6                   56         15.6
# 2  2017-01-02 02:00:00            29.8                   56         16.1
# 3  2017-01-02 03:00:00            29.8                   58         16.8
# 4  2017-01-02 04:00:00            30.2                   59         17.8
#
#    windspeed_10m  windspeed_100m  winddirection_10m  winddirection_100m  \
# 0           4.96            8.46                124                 129
# 1           4.97            8.43                120                 124
# 2           5.69            9.18                121                 123
# 3           5.49            8.88                123                 126
# 4           5.19            8.36                124                 127
#
#    windgusts_10m   Power   Location
# 0            8.8  0.3438  Location3
# 1            8.5  0.3954  Location3
# 2            9.7  0.4471  Location3
# 3            9.9  0.4988  Location3
# 4            9.4  0.5504  Location3

# %%
location4.head()
# Out:
#                   Time  temperature_2m  relativehumidity_2m  dewpoint_2m  \
# 0  2017-01-02 00:00:00            22.7                   82         18.0
# 1  2017-01-02 01:00:00            22.0                   82         17.4
# 2  2017-01-02 02:00:00            21.7                   82         17.1
# 3  2017-01-02 03:00:00            21.7                   85         17.8
# 4  2017-01-02 04:00:00            22.4                   88         19.5
#
#    windspeed_10m  windspeed_100m  winddirection_10m  winddirection_100m  \
# 0           3.21            7.60                 86                  90
# 1           3.40            7.92                 88                  94
# 2           3.81            8.41                 87                  93
# 3           3.70            8.26                 90                  97
# 4           3.85            8.50                 81                  91
#
#    windgusts_10m   Power   Location
# 0            5.3  0.3047  Location4
# 1            5.7  0.3516  Location4
# 2            6.4  0.3985  Location4
# 3            6.4  0.4454  Location4
# 4            6.6  0.4922  Location4

# %%
merged_data.head()
# Out:
#    temperature_2m  relativehumidity_2m  dewpoint_2m  windspeed_10m  \
# 0            28.5                   85         24.5           1.44
# 1            28.4                   86         24.7           2.06
# 2            26.8                   91         24.5           1.30
# 3            27.4                   88         24.3           1.30
# 4            27.3                   88         24.1           2.47
#
#    windspeed_100m  winddirection_10m  winddirection_100m  windgusts_10m  \
# 0            1.26                146                 162            1.4
# 1            3.99                151                 158            4.4
# 2            2.78                148                 150            3.2
# 3            2.69                 58                 105            1.6
# 4            4.43                 58                  84            4.0
#
#     Power  Location_Location2  Location_Location3  Location_Location4
# 0  0.1635               False               False               False
# 1  0.1424               False               False               False
# 2  0.1214               False               False               False
# 3  0.1003               False               False               False
# 4  0.0793               False               False               False

# %%
merged_data.tail()
# Out:
#         temperature_2m  relativehumidity_2m  dewpoint_2m  windspeed_10m  \
# 175195            25.5                   94         24.0           4.01
# 175196            25.3                   92         23.2           4.70
# 175197            24.9                   90         22.5           4.61
# 175198            24.9                   89         22.1           4.60
# 175199            24.9                   88         21.8           4.65
#
#         windspeed_100m  winddirection_10m  winddirection_100m  windgusts_10m  \
# 175195            6.66                  4                   8            8.2
# 175196            7.52                  1                   5            7.9
# 175197            7.57                  4                   8            7.9
# 175198            7.44                  2                   6            7.8
# 175199            7.77                  9                  12            7.8
#
#          Power  Location_Location2  Location_Location3  Location_Location4
# 175195  0.3417               False               False                True
# 175196  0.3342               False               False                True
# 175197  0.3267               False               False                True
# 175198  0.3192               False               False                True
# 175199  0.3117               False               False                True

# %%
merged_data.head(10)
# Out:
#    temperature_2m  relativehumidity_2m  dewpoint_2m  windspeed_10m  \
# 0            28.5                   85         24.5           1.44
# 1            28.4                   86         24.7           2.06
# 2            26.8                   91         24.5           1.30
# 3            27.4                   88         24.3           1.30
# 4            27.3                   88         24.1           2.47
# 5            27.6                   90         25.2           2.73
# 6            26.7                   92         24.9           2.10
# 7            28.4                   91         26.1           3.10
# 8            30.2                   88         27.0           3.54
# 9            34.0                   82         29.1           3.44
#
#    windspeed_100m  winddirection_10m  winddirection_100m  windgusts_10m  \
# 0            1.26                146                 162            1.4
# 1            3.99                151                 158            4.4
# 2            2.78                148                 150            3.2
# 3            2.69                 58                 105            1.6
# 4            4.43                 58                  84            4.0
# 5            5.59                 66                  80            4.5
# 6            5.82                 65                  78            4.7
# 7            6.24                 69                  78            4.8
# 8            6.89                 74                  81            5.8
# 9            6.01                 82                  86            6.5
#
#     Power  Location_Location2  Location_Location3  Location_Location4
# 0  0.1635               False               False               False
# 1  0.1424               False               False               False
# 2  0.1214               False               False               False
# 3  0.1003               False               False               False
# 4  0.0793               False               False               False
# 5  0.0778               False               False               False
# 6  0.0959               False               False               False
# 7  0.1141               False               False               False
# 8  0.1322               False               False               False
# 9  0.1503               False               False               False
